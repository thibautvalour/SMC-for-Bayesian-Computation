# %%
import numpy as np 
import matplotlib.pyplot as plt
from init import init_Y
from metrics import distance

# %%
Y = init_Y()
results = {f'sim_{k}' : np.load(f'results_dic/results_{k}.npy', allow_pickle=True).item() for k in range(1, 11)}

# %%
# hist of size of Xs 
fig,((ax1, ax2), (ax3,ax4),(ax5,ax6),(ax7,ax8),(ax9,ax10)) = plt.subplots(5, 2,figsize=(15,15))
ax1.hist(list(map(lambda L : len([x for x in L if x!= 0]), results['sim_1']['Xs'][-1])), bins=50, alpha=0.5,label='salut')
ax2.hist(list(map(lambda L : len([x for x in L if x!= 0]), results['sim_2']['Xs'][-1])), bins=50, alpha=0.5)
ax3.hist(list(map(lambda L : len([x for x in L if x!= 0]), results['sim_3']['Xs'][-1])), bins=50, alpha=0.5)
ax4.hist(list(map(lambda L : len([x for x in L if x!= 0]), results['sim_4']['Xs'][-1])), bins=50, alpha=0.5)
ax5.hist(list(map(lambda L : len([x for x in L if x!= 0]), results['sim_5']['Xs'][-1])), bins=50, alpha=0.5)
ax6.hist(list(map(lambda L : len([x for x in L if x!= 0]), results['sim_6']['Xs'][-1])), bins=50, alpha=0.5)
ax7.hist(list(map(lambda L : len([x for x in L if x!= 0]), results['sim_7']['Xs'][-1])), bins=50, alpha=0.5)
ax8.hist(list(map(lambda L : len([x for x in L if x!= 0]), results['sim_8']['Xs'][-1])), bins=50, alpha=0.5)
ax9.hist(list(map(lambda L : len([x for x in L if x!= 0]), results['sim_9']['Xs'][-1])), bins=50, alpha=0.5)
ax10.hist(list(map(lambda L : len([x for x in L if x!= 0]), results['sim_10']['Xs'][-1])), bins=50, alpha=0.5)
# fig.suptitle('Histogramme du nombre de génotypes distincts')
ax1.text(0.9, 0.9, 'Simulation 1',transform=ax1.transAxes, ha="right")
ax2.text(0.9, 0.9, 'Simulation 2',transform=ax2.transAxes, ha="right")
ax3.text(0.9, 0.9, 'Simulation 3',transform=ax3.transAxes, ha="right")
ax4.text(0.9, 0.9, 'Simulation 4',transform=ax4.transAxes, ha="right")
ax5.text(0.9, 0.9, 'Simulation 5',transform=ax5.transAxes, ha="right")
ax6.text(0.9, 0.9, 'Simulation 6',transform=ax6.transAxes, ha="right")
ax7.text(0.9, 0.9, 'Simulation 7',transform=ax7.transAxes, ha="right")
ax8.text(0.9, 0.9, 'Simulation 8',transform=ax8.transAxes, ha="right")
ax9.text(0.9, 0.9, 'Simulation 9',transform=ax9.transAxes, ha="right")
ax10.text(0.9, 0.9, 'Simulation 10',transform=ax10.transAxes, ha="right")
# Out:
# Text(0.9, 0.9, 'Simulation 10')

# %% [markdown]
# Idée : Il y a beaucoup de scénario avec peu de génotype distincts. Y a un nombre significatif de scénario avec plus de 400 génotypes distincts. La métrique n'encourage pas le fait d'avoir le même nombre de génotypes que le y, c'est dû au fait que on divise par n dans rho. On peut avoir un nombre de génome différent sans pour autant que le rho soit grand

# %%
# hist of size of max of Xs
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(10, 5))
ax1.hist(list(map(max, results['sim_1']['Xs'][-1])), bins=50, alpha=0.5)
ax2.hist(list(map(max, results['sim_2']['Xs'][-1])), bins=50, alpha=0.5)
ax3.hist(list(map(max, results['sim_3']['Xs'][-1])), bins=50, alpha=0.5)
plt.show()

# %%
fig,((ax1, ax2), (ax3,ax4),(ax5,ax6),(ax7,ax8),(ax9,ax10)) = plt.subplots(5, 2,figsize=(15,15))
ax1.hist(list(map(lambda L : max(L)/np.sum(L), results['sim_1']['Xs'][-1])), bins=50, alpha=0.5,label='salut')
ax3.hist(list(map(lambda L : max(L)/np.sum(L), results['sim_3']['Xs'][-1])), bins=50, alpha=0.5)
ax2.hist(list(map(lambda L : max(L)/np.sum(L), results['sim_2']['Xs'][-1])), bins=50, alpha=0.5)
ax4.hist(list(map(lambda L : max(L)/np.sum(L), results['sim_4']['Xs'][-1])), bins=50, alpha=0.5)
ax5.hist(list(map(lambda L : max(L)/np.sum(L), results['sim_5']['Xs'][-1])), bins=50, alpha=0.5)
ax6.hist(list(map(lambda L : max(L)/np.sum(L), results['sim_6']['Xs'][-1])), bins=50, alpha=0.5)
ax7.hist(list(map(lambda L : max(L)/np.sum(L), results['sim_7']['Xs'][-1])), bins=50, alpha=0.5)
ax8.hist(list(map(lambda L : max(L)/np.sum(L), results['sim_8']['Xs'][-1])), bins=50, alpha=0.5)
ax9.hist(list(map(lambda L : max(L)/np.sum(L), results['sim_9']['Xs'][-1])), bins=50, alpha=0.5)
ax10.hist(list(map(lambda L : max(L)/np.sum(L), results['sim_10']['Xs'][-1])), bins=50, alpha=0.5)
# fig.suptitle('Histogramme de la proportion du génotype majoritaire')
ax1.text(0.9, 0.9, 'Simulation 1',transform=ax1.transAxes, ha="right")
ax2.text(0.9, 0.9, 'Simulation 2',transform=ax2.transAxes, ha="right")
ax3.text(0.9, 0.9, 'Simulation 3',transform=ax3.transAxes, ha="right")
ax4.text(0.9, 0.9, 'Simulation 4',transform=ax4.transAxes, ha="right")
ax5.text(0.9, 0.9, 'Simulation 5',transform=ax5.transAxes, ha="right")
ax6.text(0.9, 0.9, 'Simulation 6',transform=ax6.transAxes, ha="right")
ax7.text(0.9, 0.9, 'Simulation 7',transform=ax7.transAxes, ha="right")
ax8.text(0.9, 0.9, 'Simulation 8',transform=ax8.transAxes, ha="right")
ax9.text(0.9, 0.9, 'Simulation 9',transform=ax9.transAxes, ha="right")
ax10.text(0.9, 0.9, 'Simulation 10',transform=ax10.transAxes, ha="right")
# Out:
# Text(0.9, 0.9, 'Simulation 10')

# %%
fig,((ax1, ax2), (ax3,ax4),(ax5,ax6),(ax7,ax8),(ax9,ax10)) = plt.subplots(5, 2,figsize=(15,15))
ax1.hist(list(map(np.sum, results['sim_1']['Xs'][-1])), bins=50, alpha=0.5,label='salut')
ax3.hist(list(map(np.sum, results['sim_3']['Xs'][-1])), bins=50, alpha=0.5)
ax2.hist(list(map(np.sum, results['sim_2']['Xs'][-1])), bins=50, alpha=0.5)
ax4.hist(list(map(np.sum, results['sim_4']['Xs'][-1])), bins=50, alpha=0.5)
ax5.hist(list(map(np.sum, results['sim_5']['Xs'][-1])), bins=50, alpha=0.5)
ax6.hist(list(map(np.sum, results['sim_6']['Xs'][-1])), bins=50, alpha=0.5)
ax7.hist(list(map(np.sum, results['sim_7']['Xs'][-1])), bins=50, alpha=0.5)
ax8.hist(list(map(np.sum, results['sim_8']['Xs'][-1])), bins=50, alpha=0.5)
ax9.hist(list(map(np.sum, results['sim_9']['Xs'][-1])), bins=50, alpha=0.5)
ax10.hist(list(map(np.sum, results['sim_10']['Xs'][-1])), bins=50, alpha=0.5)
# fig.suptitle("Histogramme du nombre d'individus par scénario")
ax1.text(0.9, 0.9, 'Simulation 1',transform=ax1.transAxes, ha="right")
ax2.text(0.9, 0.9, 'Simulation 2',transform=ax2.transAxes, ha="right")
ax3.text(0.9, 0.9, 'Simulation 3',transform=ax3.transAxes, ha="right")
ax4.text(0.9, 0.9, 'Simulation 4',transform=ax4.transAxes, ha="right")
ax5.text(0.9, 0.9, 'Simulation 5',transform=ax5.transAxes, ha="right")
ax6.text(0.9, 0.9, 'Simulation 6',transform=ax6.transAxes, ha="right")
ax7.text(0.9, 0.9, 'Simulation 7',transform=ax7.transAxes, ha="right")
ax8.text(0.9, 0.9, 'Simulation 8',transform=ax8.transAxes, ha="right")
ax9.text(0.9, 0.9, 'Simulation 9',transform=ax9.transAxes, ha="right")
ax10.text(0.9, 0.9, 'Simulation 10',transform=ax10.transAxes, ha="right")
# Out:
# Text(0.9, 0.9, 'Simulation 10')

# %%
from lmfit.models import SkewedGaussianModel
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[99], line 1
# ----> 1 from lmfit.models import SkewedGaussianModel
#
# ModuleNotFoundError: No module named 'lmfit'

# %%
model = SkewedGaussianModel()

# set initial parameter values
params = model.make_params(amplitude=10, center=0, sigma=1, gamma=0)

# adjust parameters  to best fit data.
result = model.fit(yvals, params, x=xvals)

print(result.fit_report())
pylab.plot(xvals, yvals)
pylab.plot(xvals, result.best_fit)

# %% [markdown]
# Pic à 1/2 sont des populations de type [1,1]. Correspond à des simulations certainement proche de l'échec donc réechantillonnage probable.
#
# Pic à 1 c'est des pop de type [1,0]. Correspond à des simulations proche de mourir en tout

# %%
L=results['sim_1']['Xs'][-1]
liste=[]
for i in range(1000):
    if max(L[i])/np.sum(L[i])==1 and max(L[i])>1:
        print(L[i])
        liste.append(i)
# Out:
# [0, 2]
# [0, 2]
# [0, 2]
# [2, 0]
# [0, 2]

# %% [markdown]
# Idée : Poids du génotype contenant le plus de gens

# %%
fig,((ax1, ax2), (ax3,ax4),(ax5,ax6),(ax7,ax8),(ax9,ax10)) = plt.subplots(5, 2,figsize=(15,15))
ax1.hist(results['sim_1']['thetas'][-1][:,0]/(results['sim_1']['thetas'][-1][:,1]+results['sim_1']['thetas'][-1][:,0]+results['sim_1']['thetas'][-1][:,2]), bins=50, alpha=0.5)
ax2.hist(results['sim_2']['thetas'][-1][:,0]/(results['sim_2']['thetas'][-1][:,1]+results['sim_2']['thetas'][-1][:,0]+results['sim_2']['thetas'][-1][:,2]), bins=50, alpha=0.5,label='salut')
ax3.hist(results['sim_3']['thetas'][-1][:,0]/(results['sim_3']['thetas'][-1][:,1]+results['sim_3']['thetas'][-1][:,0]+results['sim_3']['thetas'][-1][:,2]), bins=50, alpha=0.5)
ax4.hist(results['sim_4']['thetas'][-1][:,0]/(results['sim_4']['thetas'][-1][:,1]+results['sim_4']['thetas'][-1][:,0]+results['sim_4']['thetas'][-1][:,2]), bins=50, alpha=0.5)
ax5.hist(results['sim_5']['thetas'][-1][:,0]/(results['sim_5']['thetas'][-1][:,1]+results['sim_5']['thetas'][-1][:,0]+results['sim_5']['thetas'][-1][:,2]), bins=50, alpha=0.5)
ax6.hist(results['sim_6']['thetas'][-1][:,0]/(results['sim_6']['thetas'][-1][:,1]+results['sim_6']['thetas'][-1][:,0]+results['sim_6']['thetas'][-1][:,2]), bins=50, alpha=0.5)
ax7.hist(results['sim_7']['thetas'][-1][:,0]/(results['sim_7']['thetas'][-1][:,1]+results['sim_7']['thetas'][-1][:,0]+results['sim_7']['thetas'][-1][:,2]), bins=50, alpha=0.5)
ax8.hist(results['sim_8']['thetas'][-1][:,0]/(results['sim_8']['thetas'][-1][:,1]+results['sim_8']['thetas'][-1][:,0]+results['sim_8']['thetas'][-1][:,2]), bins=50, alpha=0.5)
ax9.hist(results['sim_9']['thetas'][-1][:,0]/(results['sim_9']['thetas'][-1][:,1]+results['sim_9']['thetas'][-1][:,0]+results['sim_9']['thetas'][-1][:,2]), bins=50, alpha=0.5)
ax10.hist(results['sim_10']['thetas'][-1][:,0]/(results['sim_10']['thetas'][-1][:,1]+results['sim_10']['thetas'][-1][:,0]+results['sim_10']['thetas'][-1][:,2]), bins=50, alpha=0.5)
# fig.suptitle('Histogramme du taux de naissance phi')
ax1.text(0.9, 0.9, 'Simulation 1',transform=ax1.transAxes, ha="right")
ax2.text(0.9, 0.9, 'Simulation 2',transform=ax2.transAxes, ha="right")
ax3.text(0.9, 0.9, 'Simulation 3',transform=ax3.transAxes, ha="right")
ax4.text(0.9, 0.9, 'Simulation 4',transform=ax4.transAxes, ha="right")
ax5.text(0.9, 0.9, 'Simulation 5',transform=ax5.transAxes, ha="right")
ax6.text(0.9, 0.9, 'Simulation 6',transform=ax6.transAxes, ha="right")
ax7.text(0.9, 0.9, 'Simulation 7',transform=ax7.transAxes, ha="right")
ax8.text(0.9, 0.9, 'Simulation 8',transform=ax8.transAxes, ha="right")
ax9.text(0.9, 0.9, 'Simulation 9',transform=ax9.transAxes, ha="right")
ax10.text(0.9, 0.9, 'Simulation 10',transform=ax10.transAxes, ha="right")
# Out:
# Text(0.9, 0.9, 'Simulation 10')

# %%
fig,((ax1, ax2), (ax3,ax4),(ax5,ax6),(ax7,ax8),(ax9,ax10)) = plt.subplots(5, 2,figsize=(15,15))
ax1.hist(results['sim_1']['thetas'][-1][:,1]/(results['sim_1']['thetas'][-1][:,1]+results['sim_1']['thetas'][-1][:,0]+results['sim_1']['thetas'][-1][:,2]), bins=50, alpha=0.5)
ax2.hist(results['sim_2']['thetas'][-1][:,1]/(results['sim_2']['thetas'][-1][:,1]+results['sim_2']['thetas'][-1][:,0]+results['sim_2']['thetas'][-1][:,2]), bins=50, alpha=0.5,label='salut')
ax3.hist(results['sim_3']['thetas'][-1][:,1]/(results['sim_3']['thetas'][-1][:,1]+results['sim_3']['thetas'][-1][:,0]+results['sim_3']['thetas'][-1][:,2]), bins=50, alpha=0.5)
ax4.hist(results['sim_4']['thetas'][-1][:,1]/(results['sim_4']['thetas'][-1][:,1]+results['sim_4']['thetas'][-1][:,0]+results['sim_4']['thetas'][-1][:,2]), bins=50, alpha=0.5)
ax5.hist(results['sim_5']['thetas'][-1][:,1]/(results['sim_5']['thetas'][-1][:,1]+results['sim_5']['thetas'][-1][:,0]+results['sim_5']['thetas'][-1][:,2]), bins=50, alpha=0.5)
ax6.hist(results['sim_6']['thetas'][-1][:,1]/(results['sim_6']['thetas'][-1][:,1]+results['sim_6']['thetas'][-1][:,0]+results['sim_6']['thetas'][-1][:,2]), bins=50, alpha=0.5)
ax7.hist(results['sim_7']['thetas'][-1][:,1]/(results['sim_7']['thetas'][-1][:,1]+results['sim_7']['thetas'][-1][:,0]+results['sim_7']['thetas'][-1][:,2]), bins=50, alpha=0.5)
ax8.hist(results['sim_8']['thetas'][-1][:,1]/(results['sim_8']['thetas'][-1][:,1]+results['sim_8']['thetas'][-1][:,0]+results['sim_8']['thetas'][-1][:,2]), bins=50, alpha=0.5)
ax9.hist(results['sim_9']['thetas'][-1][:,1]/(results['sim_9']['thetas'][-1][:,1]+results['sim_9']['thetas'][-1][:,0]+results['sim_9']['thetas'][-1][:,2]), bins=50, alpha=0.5)
ax10.hist(results['sim_10']['thetas'][-1][:,1]/(results['sim_10']['thetas'][-1][:,1]+results['sim_10']['thetas'][-1][:,0]+results['sim_10']['thetas'][-1][:,2]), bins=50, alpha=0.5)
# fig.suptitle('Histogramme du taux de mortalité tau')
ax1.text(0.9, 0.9, 'Simulation 1',transform=ax1.transAxes, ha="right")
ax2.text(0.9, 0.9, 'Simulation 2',transform=ax2.transAxes, ha="right")
ax3.text(0.9, 0.9, 'Simulation 3',transform=ax3.transAxes, ha="right")
ax4.text(0.9, 0.9, 'Simulation 4',transform=ax4.transAxes, ha="right")
ax5.text(0.9, 0.9, 'Simulation 5',transform=ax5.transAxes, ha="right")
ax6.text(0.9, 0.9, 'Simulation 6',transform=ax6.transAxes, ha="right")
ax7.text(0.9, 0.9, 'Simulation 7',transform=ax7.transAxes, ha="right")
ax8.text(0.9, 0.9, 'Simulation 8',transform=ax8.transAxes, ha="right")
ax9.text(0.9, 0.9, 'Simulation 9',transform=ax9.transAxes, ha="right")
ax10.text(0.9, 0.9, 'Simulation 10',transform=ax10.transAxes, ha="right")
# Out:
# Text(0.9, 0.9, 'Simulation 10')

# %%
fig,((ax1, ax2), (ax3,ax4),(ax5,ax6),(ax7,ax8),(ax9,ax10)) = plt.subplots(5, 2,figsize=(15,15))
ax1.hist(results['sim_1']['thetas'][-1][:,2]/(results['sim_1']['thetas'][-1][:,1]+results['sim_1']['thetas'][-1][:,0]+results['sim_1']['thetas'][-1][:,2]), bins=50, alpha=0.5)
ax2.hist(results['sim_2']['thetas'][-1][:,2]/(results['sim_2']['thetas'][-1][:,1]+results['sim_2']['thetas'][-1][:,0]+results['sim_2']['thetas'][-1][:,2]), bins=50, alpha=0.5,label='salut')
ax3.hist(results['sim_3']['thetas'][-1][:,2]/(results['sim_3']['thetas'][-1][:,1]+results['sim_3']['thetas'][-1][:,0]+results['sim_3']['thetas'][-1][:,2]), bins=50, alpha=0.5)
ax4.hist(results['sim_4']['thetas'][-1][:,2]/(results['sim_4']['thetas'][-1][:,1]+results['sim_4']['thetas'][-1][:,0]+results['sim_4']['thetas'][-1][:,2]), bins=50, alpha=0.5)
ax5.hist(results['sim_5']['thetas'][-1][:,2]/(results['sim_5']['thetas'][-1][:,1]+results['sim_5']['thetas'][-1][:,0]+results['sim_5']['thetas'][-1][:,2]), bins=50, alpha=0.5)
ax6.hist(results['sim_6']['thetas'][-1][:,2]/(results['sim_6']['thetas'][-1][:,1]+results['sim_6']['thetas'][-1][:,0]+results['sim_6']['thetas'][-1][:,2]), bins=50, alpha=0.5)
ax7.hist(results['sim_7']['thetas'][-1][:,2]/(results['sim_7']['thetas'][-1][:,1]+results['sim_7']['thetas'][-1][:,0]+results['sim_7']['thetas'][-1][:,2]), bins=50, alpha=0.5)
ax8.hist(results['sim_8']['thetas'][-1][:,2]/(results['sim_8']['thetas'][-1][:,1]+results['sim_8']['thetas'][-1][:,0]+results['sim_8']['thetas'][-1][:,2]), bins=50, alpha=0.5)
ax9.hist(results['sim_9']['thetas'][-1][:,2]/(results['sim_9']['thetas'][-1][:,1]+results['sim_9']['thetas'][-1][:,0]+results['sim_9']['thetas'][-1][:,2]), bins=50, alpha=0.5)
ax10.hist(results['sim_10']['thetas'][-1][:,2]/(results['sim_10']['thetas'][-1][:,1]+results['sim_10']['thetas'][-1][:,0]+results['sim_10']['thetas'][-1][:,2]), bins=50, alpha=0.5)
# fig.suptitle('Histogramme du taux de mutation xi')
ax1.text(0.9, 0.9, 'Simulation 1',transform=ax1.transAxes, ha="right")
ax2.text(0.9, 0.9, 'Simulation 2',transform=ax2.transAxes, ha="right")
ax3.text(0.9, 0.9, 'Simulation 3',transform=ax3.transAxes, ha="right")
ax4.text(0.9, 0.9, 'Simulation 4',transform=ax4.transAxes, ha="right")
ax5.text(0.9, 0.9, 'Simulation 5',transform=ax5.transAxes, ha="right")
ax6.text(0.9, 0.9, 'Simulation 6',transform=ax6.transAxes, ha="right")
ax7.text(0.9, 0.9, 'Simulation 7',transform=ax7.transAxes, ha="right")
ax8.text(0.9, 0.9, 'Simulation 8',transform=ax8.transAxes, ha="right")
ax9.text(0.9, 0.9, 'Simulation 9',transform=ax9.transAxes, ha="right")
ax10.text(0.9, 0.9, 'Simulation 10',transform=ax10.transAxes, ha="right")
# Out:
# Text(0.9, 0.9, 'Simulation 10')

# %%
# Mean and variance of phi for each simulation
for k in range(1, 11):
    print(f'phi : sim_{k} mean = {np.mean(results[f"sim_{k}"]["thetas"][-1][:, 0])}, std = {np.std(results[f"sim_{k}"]["thetas"][-1][:, 0])}')
# Out:
# phi : sim_1 mean = 10.878484918815122, std = 10.308186591304187
# phi : sim_2 mean = 10.53375498351377, std = 10.709646682685642
# phi : sim_3 mean = 9.799891340970639, std = 9.651710266702828
# phi : sim_4 mean = 9.916492728472408, std = 9.865423690847093
# phi : sim_5 mean = 9.534055302548982, std = 9.908424207061362
# phi : sim_6 mean = 10.162864743993111, std = 9.955817166434779
# phi : sim_7 mean = 9.81413659005326, std = 9.73244209274976
# phi : sim_8 mean = 9.86383930553292, std = 9.844073028975862
# phi : sim_9 mean = 10.435512920982339, std = 10.562316436449935
# phi : sim_10 mean = 9.741265658670654, std = 9.480615171663135

# %%
# Mean and variance of tau for each simulation
for k in range(1, 11):
    print(f'tau : sim_{k} mean = {np.mean(results[f"sim_{k}"]["thetas"][-1][:, 1])}, std = {np.std(results[f"sim_{k}"]["thetas"][-1][:, 1])}')
# Out:
# tau : sim_1 mean = 5.3948171693213975, std = 6.728116149690718
# tau : sim_2 mean = 5.375115800077069, std = 7.102922465289202
# tau : sim_3 mean = 4.820228503571122, std = 5.938448548971215
# tau : sim_4 mean = 4.774326914493372, std = 6.070915225937388
# tau : sim_5 mean = 4.773659659726276, std = 6.230937200726358
# tau : sim_6 mean = 5.1564827520652035, std = 6.342890889082705
# tau : sim_7 mean = 4.9367937633044585, std = 6.04492377752251
# tau : sim_8 mean = 4.942751146496932, std = 6.087839100941142
# tau : sim_9 mean = 5.258007641092822, std = 6.730321226750291
# tau : sim_10 mean = 4.828662630618147, std = 5.79804706840167

# %%
# Mean and variance of xi for each simulation
for k in range(1, 11):
    print(f'xi : sim_{k} mean = {np.mean(results[f"sim_{k}"]["thetas"][-1][:, 2])}, std = {np.std(results[f"sim_{k}"]["thetas"][-1][:, 2])}')
# Out:
# xi : sim_1 mean = 0.2625031694481577, std = 0.045930508254586166
# xi : sim_2 mean = 0.2626035027848841, std = 0.04647422493699997
# xi : sim_3 mean = 0.26263028996230914, std = 0.045891121553471345
# xi : sim_4 mean = 0.26224145341370214, std = 0.04647444168350592
# xi : sim_5 mean = 0.2625961120181688, std = 0.04684250905963281
# xi : sim_6 mean = 0.26251513702842033, std = 0.04680273213327477
# xi : sim_7 mean = 0.2608229121210812, std = 0.045077120073388544
# xi : sim_8 mean = 0.26349780379674803, std = 0.04525296230708485
# xi : sim_9 mean = 0.26178051702995553, std = 0.04509211695494634
# xi : sim_10 mean = 0.2610818694147599, std = 0.04399170317273021
